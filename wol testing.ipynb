# %%
computer_list = {}



for line in open('wakeonlan.xml'):
    if 'Name' in line:
        print(line)
    elif 'MAC' in line:
        print(line)
# Out:
#     <Name>TCHS 1</Name>
#
#     <MAC>94c69180eb02</MAC>
#
#     <Name>TCHS 10</Name>
#
#     <MAC>94c69180f33f</MAC>
#
#     <Name>TCHS 11</Name>
#
#     <MAC>94c69180f4fc</MAC>
#
#     <Name>TCHS 12</Name>
#
#     <MAC>94c69180f49e</MAC>
#
#     <Name>TCHS 13</Name>
#
#     <MAC>94c69180ec5d</MAC>
#
#     <Name>TCHS 14</Name>
#
#     <MAC>94c69180fdd3</MAC>
#
#     <Name>TCHS 15</Name>
#
#     <MAC>94c69180e9af</MAC>
#
#     <Name>TCHS 16</Name>
#
#     <MAC>94c69180f187</MAC>
#
#     <Name>TCHS 17</Name>
#
#     <MAC>94c69180fa11</MAC>
#
#     <Name>TCHS 18</Name>
#
#     <MAC>94c6917c0b88</MAC>
#
#     <Name>TCHS 19</Name>
#
#     <MAC>94c69178db54</MAC>
#
#     <Name>TCHS 2</Name>
#
#     <MAC>94c69180fafb</MAC>
#
#     <Name>TCHS 20</Name>
#
#     <MAC>94c6917c0bda</MAC>
#
#     <Name>TCHS 21</Name>
#
#     <MAC>94c6917deded</MAC>
#
#     <Name>TCHS 22</Name>
#
#     <MAC>94c6917dd949</MAC>
#
#     <Name>TCHS 23</Name>
#
#     <MAC>94c69180fcc0</MAC>
#
# ...
